# %%
import pandas as pd
import numpy as np


filename = r'/content/Hot Dog Classification Survey_ Is it a Sandwich_  (Responses) - Form Responses 1.csv'

df = pd.read_csv(filename)
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-f539e3a72141> in <cell line: 7>()
#       5 filename = r'/content/Hot Dog Classification Survey_ Is it a Sandwich_  (Responses) - Form Responses 1.csv'
#       6
# ----> 7 df = pd.read_csv(filename)
#       8 df.head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
# ...

# %%
# rename columns
# get rid of graduate student responses (outside scope) and then remove that column (irrelevant)

df.rename(columns = {'Do you believe that a hotdog falls under the category of a sandwich?': 'hotdog_response',
                     'What is the rationale behind your opinion?':'rationale', 'What is your field of study or major?':'major',
                     'If you are an undergraduate, what is your current academic year?':'class',
                     'What state or country were you born in?':'place_of_birth',
                     'Are you currently enrolled as an undergraduate or graduate student at the University of Virginia?':'grad_status'}, inplace=True)
print(df.head())
# Out:
#             Timestamp hotdog_response  \
# 0  1/18/2024 14:18:57              No
# 1  1/18/2024 14:19:44              No
# 2  1/18/2024 14:20:52              No
# 3  1/18/2024 14:21:10              No
# 4  1/18/2024 14:22:38             Yes
#
#                                            rationale    grad_status  \
# 0  If you asked for a sandwich and someone gave y...  Undergraduate
# 1                                                NaN       Graduate
# 2                  Society doesn’t view it that way   Undergraduate
# 3  If a sandwich has meat in it, it is sliced. A ...  Undergraduate
# 4  Merriam Webster Dictionary definition of sandwich  Undergraduate
#
#                  major        class           place_of_birth
# 0  Systems engineering  Fourth year                 Virginia
# 1                  NaN          NaN                      NaN
# 2    Computer science    Third Year           United States
# 3   Astronomy-Physics   Fourth year                 New York
# ...

# %%
df = df[df['grad_status'] != 'Graduate']
print(df)
# Out:
#              Timestamp hotdog_response  \
# 0   1/18/2024 14:18:57              No
# 2   1/18/2024 14:20:52              No
# 3   1/18/2024 14:21:10              No
# 4   1/18/2024 14:22:38             Yes
# 5   1/18/2024 14:22:55              No
# ..                 ...             ...
# 86  1/21/2024 21:44:01              No
# 87  1/22/2024 16:16:44             Yes
# 88  1/22/2024 19:33:29             Yes
# 89  1/22/2024 20:10:45             Yes
# 90  1/22/2024 20:56:27             Yes
#
#                                             rationale    grad_status  \
# 0   If you asked for a sandwich and someone gave y...  Undergraduate
# 2                   Society doesn’t view it that way   Undergraduate
# 3   If a sandwich has meat in it, it is sliced. A ...  Undergraduate
# 4   Merriam Webster Dictionary definition of sandwich  Undergraduate
# 5   If I asked for a sandwich and somebody gave me...  Undergraduate
# ..                                                ...            ...
# ...

# %%
df = df.drop('Timestamp', axis=1)
df = df.drop('grad_status', axis=1)
df.head()
# Out:
#   hotdog_response                                          rationale  \
# 0              No  If you asked for a sandwich and someone gave y...
# 2              No                  Society doesn’t view it that way
# 3              No  If a sandwich has meat in it, it is sliced. A ...
# 4             Yes  Merriam Webster Dictionary definition of sandwich
# 5              No  If I asked for a sandwich and somebody gave me...
#
#                  major        class           place_of_birth
# 0  Systems engineering  Fourth year                 Virginia
# 2    Computer science    Third Year           United States
# 3   Astronomy-Physics   Fourth year                 New York
# 4     Computer Science  Fourth year  Virginia, United States
# 5        Media Studies   Third Year                 Virginia

# %%
import matplotlib.pyplot as plt

counts = df['hotdog_response'].value_counts().plot(kind='bar')

# %% [markdown]
# This data is limited in that it will be hard to conduct analysis on the 'rationale' variable. We thus have a dataset with only a few variables worth exploring and not a lot of opportunity to explore the causality.
