# %% [markdown]
# ### Is a Hotdog a Sandwich Survery Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('DS-4002-sp24-survey-results.xlsx')
df
# Out:
#                  Timestamp  \
# 0  2024-01-18 14:18:57.066
# 1  2024-01-18 14:19:43.773
# 2  2024-01-18 14:20:51.525
# 3  2024-01-18 14:21:09.905
# 4  2024-01-18 14:22:38.459
# ..                     ...
# 86 2024-01-21 21:44:00.821
# 87 2024-01-22 16:16:43.559
# 88 2024-01-22 19:33:29.226
# 89 2024-01-22 20:10:44.764
# 90 2024-01-22 20:56:27.004
#
#    Do you believe that a hotdog falls under the category of a sandwich?  \
# 0                                                  No
# 1                                                  No
# 2                                                  No
# 3                                                  No
# 4                                                 Yes
# ..                                                ...
# 86                                                 No
# 87                                                Yes
# 88                                                Yes
# 89                                                Yes
# ...

# %%
# rename column 2 as Sandwich?
# rename column 3 as Rationale?
df.columns = ['Timestamp', 'Sandwich?', 'Rationale?', 'Degree Type?', 'Major?', 'Year', 'Birthplace']
df
# Out:
#                  Timestamp Sandwich?  \
# 0  2024-01-18 14:18:57.066        No
# 1  2024-01-18 14:19:43.773        No
# 2  2024-01-18 14:20:51.525        No
# 3  2024-01-18 14:21:09.905        No
# 4  2024-01-18 14:22:38.459       Yes
# ..                     ...       ...
# 86 2024-01-21 21:44:00.821        No
# 87 2024-01-22 16:16:43.559       Yes
# 88 2024-01-22 19:33:29.226       Yes
# 89 2024-01-22 20:10:44.764       Yes
# 90 2024-01-22 20:56:27.004       Yes
#
#                                            Rationale?   Degree Type?  \
# 0   If you asked for a sandwich and someone gave y...  Undergraduate
# 1                                                 NaN       Graduate
# 2                   Society doesn’t view it that way   Undergraduate
# 3   If a sandwich has meat in it, it is sliced. A ...  Undergraduate
# 4   Merriam Webster Dictionary definition of sandwich  Undergraduate
# ..                                                ...            ...
# ...

# %%
# remove Degree Type Graduate
df = df[df['Degree Type?'] != 'Graduate']
df
# Out:
#                  Timestamp Sandwich?  \
# 0  2024-01-18 14:18:57.066        No
# 2  2024-01-18 14:20:51.525        No
# 3  2024-01-18 14:21:09.905        No
# 4  2024-01-18 14:22:38.459       Yes
# 5  2024-01-18 14:22:54.865        No
# ..                     ...       ...
# 86 2024-01-21 21:44:00.821        No
# 87 2024-01-22 16:16:43.559       Yes
# 88 2024-01-22 19:33:29.226       Yes
# 89 2024-01-22 20:10:44.764       Yes
# 90 2024-01-22 20:56:27.004       Yes
#
#                                            Rationale?   Degree Type?  \
# 0   If you asked for a sandwich and someone gave y...  Undergraduate
# 2                   Society doesn’t view it that way   Undergraduate
# 3   If a sandwich has meat in it, it is sliced. A ...  Undergraduate
# 4   Merriam Webster Dictionary definition of sandwich  Undergraduate
# 5   If I asked for a sandwich and somebody gave me...  Undergraduate
# ..                                                ...            ...
# ...

# %%
# plot number of people Sandwich yes vs no
df['Sandwich?'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
# group by year, and plot number of people Sandwich yes vs no
# group by year and sandwich status, and plot number of people with different colors for yes and no
df.groupby(['Year', 'Sandwich?'])['Sandwich?'].count().unstack().plot(kind='bar', color=['blue', 'red'])
# Out:
# <Axes: xlabel='Year'>

# %%
# Create pie chart of yes vs no
df['Sandwich?'].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='Sandwich?'>
